# %% [markdown]
# # **Fundamentos de HTML y CSS**

# %% [markdown]
# ## **Objetivo**
# Al finalizar este módulo, el estudiante será capaz de:
#
# * Comprender y aplicar correctamente la estructura básica de un documento HTML5.
#
# * Utilizar etiquetas semánticas para mejorar la legibilidad y accesibilidad del contenido web.
#
# * Crear formularios estructurados, con campos adecuados y validaciones básicas.

# %% [markdown]
# # Tabla de etiquetas HTML
#
# | Etiqueta       | Descripción                                                                 |
# |----------------|------------------------------------------------------------------------------|
# | &lt;a&gt;         | Define un hipervínculo (enlace).                                           |
# | &lt;abbr&gt;      | Define una abreviatura o acrónimo.                                         |
# | &lt;address&gt;   | Proporciona información de contacto.                                       |
# | &lt;article&gt;   | Define contenido independiente y autocontenible.                           |
# | &lt;aside&gt;     | Contenido lateral, como barras laterales o notas.                          |
# | &lt;audio&gt;     | Inserta un archivo de audio.                                               |
# | &lt;b&gt;          | Texto en negrita sin importancia semántica.                               |
# | &lt;base&gt;      | Especifica la URL base para los enlaces relativos.                         |
# | &lt;bdi&gt;        | Aísla una parte de texto con dirección bidireccional.                     |
# | &lt;bdo&gt;        | Anula la dirección de texto (de izquierda a derecha o viceversa).         |
# | &lt;blockquote&gt;| Define una cita larga de otro contenido.                                   |
# | &lt;body&gt;      | Contiene el contenido visible de una página.                               |
# | &lt;br&gt;        | Salto de línea.                                                            |
# | &lt;button&gt;    | Crea un botón interactivo.                                                 |
# | &lt;canvas&gt;    | Área para gráficos dibujados mediante JavaScript.                          |
# | &lt;caption&gt;   | Título de una tabla.                                                       |
# | &lt;cite&gt;      | Define el título de una obra (libro, película, etc.).                      |
# | &lt;code&gt;      | Representa código fuente.                                                  |
# | &lt;col&gt;       | Define propiedades de una columna en una tabla.                            |
# | &lt;colgroup&gt;  | Agrupa una o más columnas en una tabla.                                    |
# | &lt;data&gt;      | Asocia un valor legible por máquina a un contenido.                       |
# | &lt;datalist&gt;   | Lista de opciones predefinidas para un input.                              |
# | &lt;dd&gt;         | Define una descripción en una lista de definiciones.                       |
# | &lt;del&gt;        | Texto eliminado.                                                          |
# | &lt;details&gt;    | Widget interactivo para mostrar/esconder contenido.                      |
# | &lt;dfn&gt;        | Define un término.                                                         |
# | &lt;div&gt;        | Contenedor genérico sin significado semántico.                            |
# | &lt;dl&gt;         | Lista de definiciones.                                                    |
# | &lt;dt&gt;         | Término en una lista de definiciones.                                     |
# | &lt;em&gt;         | Texto enfatizado.                                                        |
# | &lt;embed&gt;      | Inserta contenido externo (multimedia, por ejemplo).                       |
# | &lt;fieldset&gt;   | Agrupa elementos en un formulario.                                        |
# | &lt;figcaption&gt; | Leyenda de una figura.                                                     |
# | &lt;figure&gt;     | Contenido ilustrativo como imágenes o gráficos.                           |
# | &lt;footer&gt;     | Pie de página de una sección o documento.                                 |
# | &lt;form&gt;       | Define un formulario.                                                     |
# | &lt;h1&gt;-&lt;h6&gt;   | Títulos de encabezado, de mayor a menor jerarquía.                        |
# | &lt;head&gt;       | Contiene metadatos del documento.                                         |
# | &lt;header&gt;     | Cabecera de una sección o documento.                                      |
# | &lt;hr&gt;         | Línea horizontal/separador temático.                                     |
# | &lt;html&gt;       | Raíz del documento HTML.                                                  |
# | &lt;i&gt;          | Texto en cursiva sin importancia semántica.                               |
# | &lt;iframe&gt;     | Inserta un documento HTML dentro de otro.                                 |
# | &lt;img&gt;        | Inserta una imagen.                                                       |
# | &lt;input&gt;      | Campo de entrada de datos.                                                |
# | &lt;ins&gt;        | Texto insertado.                                                         |
# | &lt;kbd&gt;        | Representa la entrada del teclado del usuario.                             |
# | &lt;label&gt;      | Etiqueta para un elemento de formulario.                                  |
# | &lt;legend&gt;     | Título de un fieldset.                                                    |
# | &lt;li&gt;         | Elemento de una lista.                                                    |
# | &lt;link&gt;       | Vincula recursos externos (por ejemplo, hojas de estilo).                 |
# | &lt;main&gt;       | Contenido principal del documento.                                        |
# | &lt;map&gt;        | Define un mapa de imagen.                                                  |
# | &lt;mark&gt;       | Texto resaltado.                                                         |
# | &lt;meta&gt;       | Metadatos sobre el documento.                                             |
# | &lt;nav&gt;        | Define un bloque de navegación.                                           |
# | &lt;noscript&gt;   | Contenido alternativo si JavaScript está deshabilitado.                   |
# | &lt;object&gt;     | Contenido incrustado como multimedia o aplicaciones.                       |
# | &lt;ol&gt;         | Lista ordenada.                                                           |
# | &lt;optgroup&gt;   | Agrupa opciones dentro de un &lt;select&gt;.                                |
# | &lt;option&gt;     | Opción dentro de un &lt;select&gt;.                                         |
# | &lt;output&gt;     | Resultado de un cálculo o acción del usuario.                              |
# | &lt;p&gt;          | Define un párrafo.                                                        |
# | &lt;picture&gt;     | Contenedor para múltiples fuentes de imagen.                             |
# | &lt;pre&gt;        | Texto preformateado.                                                      |
# | &lt;progress&gt;   | Indicador de progreso.                                                    |
# | &lt;q&gt;          | Cita corta en línea.                                                     |
# | &lt;rp&gt;         | Texto alternativo para navegadores sin soporte de ruby.                   |
# | &lt;rt&gt;         | Pronunciación o traducción en anotaciones ruby.                           |
# | &lt;ruby&gt;       | Anotación ruby para caracteres asiáticos.                                 |
# | &lt;s&gt;          | Texto que ya no es relevante (tachado).                                    |
# | &lt;samp&gt;       | Muestra salida de un programa.                                            |
# | &lt;script&gt;     | Código JavaScript.                                                       |
# | &lt;section&gt;    | Sección de contenido temático.                                            |
# | &lt;select&gt;     | Menú desplegable.                                                        |
# | &lt;small&gt;      | Texto de menor importancia.                                               |
# | &lt;source&gt;     | Fuente multimedia alternativa para &lt;audio&gt; o &lt;video&gt;.         |
# | &lt;span&gt;       | Contenedor en línea sin significado semántico.                            |
# | &lt;strong&gt;     | Texto con énfasis fuerte (semántico).                                     |
# | &lt;style&gt;      | Define estilos CSS.                                                       |
# | &lt;sub&gt;        | Texto en subíndice.                                                       |
# | &lt;summary&gt;    | Título de un elemento &lt;details&gt;.                                     |
# | &lt;sup&gt;        | Texto en superíndice.                                                    |
# | &lt;svg&gt;        | Gráficos vectoriales escalables.                                          |
# | &lt;table&gt;      | Define una tabla.                                                        |
# | &lt;tbody&gt;      | Cuerpo de una tabla.                                                     |
# | &lt;td&gt;         | Celda de datos en una tabla.                                              |
# | &lt;template&gt;   | Plantilla de contenido reutilizable.                                      |
# | &lt;textarea&gt;   | Área de texto de varias líneas.                                           |
# | &lt;tfoot&gt;      | Pie de una tabla.                                                        |
# | &lt;th&gt;         | Celda de encabezado en una tabla.                                         |
# | &lt;thead&gt;      | Encabezado de una tabla.                                                 |
# | &lt;time&gt;       | Fecha u hora.                                                            |
# | &lt;title&gt;      | Título del documento (en la pestaña del navegador).                       |
# | &lt;tr&gt;         | Fila de una tabla.                                                       |
# | &lt;track&gt;      | Pistas de texto para medios (subtítulos, etc.).                          |
# | &lt;u&gt;          | Texto subrayado (sin valor semántico).                                    |
# | &lt;ul&gt;         | Lista no ordenada.                                                       |
# | &lt;var&gt;        | Representa una variable.                                                  |
# | &lt;video&gt;      | Inserta un archivo de vídeo.                                              |
# | &lt;wbr&gt;        | Sugerencia de posible punto de salto de línea.                            |

# %% [markdown]
# # Tabla de propiedades CSS
#
# | Propiedad              | Descripción                                                                 | Ejemplo                                     |
# |------------------------|-----------------------------------------------------------------------------|---------------------------------------------|
# | align-content          | Alinea varias líneas dentro de un contenedor flex o grid.                  | align-content: space-between;              |
# | align-items            | Alinea elementos hijos en el eje cruzado (flex/grid).                      | align-items: center;                        |
# | align-self             | Alineación individual de un ítem en el eje cruzado.                        | align-self: flex-end;                       |
# | animation              | Atajo para propiedades de animación.                                       | animation: fadeIn 2s ease-in-out;           |
# | animation-delay        | Retraso antes de que comience una animación.                               | animation-delay: 1s;                        |
# | animation-direction    | Dirección de reproducción de la animación.                                 | animation-direction: alternate;             |
# | animation-duration     | Duración de la animación.                                                  | animation-duration: 2s;                     |
# | animation-iteration-count | Cuántas veces se repite la animación.                                 | animation-iteration-count: infinite;        |
# | animation-name         | Nombre de la animación (keyframes).                                        | animation-name: slidein;                    |
# | animation-timing-function | Curva de velocidad de la animación.                                   | animation-timing-function: ease-in-out;     |
# | background             | Fondo del elemento (color, imagen, etc.).                                 | background: #eee url(bg.jpg) no-repeat;     |
# | background-color       | Color de fondo.                                                           | background-color: #fff;                     |
# | background-image       | Imagen de fondo.                                                          | background-image: url("fondo.jpg");         |
# | background-position    | Posición de la imagen de fondo.                                           | background-position: center center;         |
# | background-size        | Tamaño de la imagen de fondo.                                             | background-size: cover;                     |
# | border                 | Define un borde.                                                           | border: 1px solid black;                    |
# | border-radius          | Bordes redondeados.                                                       | border-radius: 10px;                        |
# | box-shadow             | Sombra alrededor del elemento.                                             | box-shadow: 0 2px 5px rgba(0,0,0,0.3);       |
# | box-sizing             | Define cómo se calculan ancho y alto.                                     | box-sizing: border-box;                     |
# | color                  | Color del texto.                                                          | color: #333;                                |
# | column-count           | Número de columnas en diseño multicolumna.                               | column-count: 3;                            |
# | column-gap             | Espacio entre columnas.                                                   | column-gap: 20px;                           |
# | cursor                 | Tipo de cursor al pasar el ratón.                                         | cursor: pointer;                            |
# | display                | Cómo se muestra un elemento.                                              | display: grid;                              |
# | flex                   | Propiedad abreviada para crecer, encoger y base.                          | flex: 1 1 auto;                             |
# | flex-basis             | Tamaño base del ítem flex.                                                | flex-basis: 200px;                          |
# | flex-direction         | Dirección del eje principal (fila o columna).                             | flex-direction: column;                     |
# | flex-grow              | Define cómo crece un ítem.                                                | flex-grow: 2;                               |
# | flex-shrink            | Define cómo se reduce un ítem.                                            | flex-shrink: 1;                             |
# | flex-wrap              | Si los ítems deben envolver.                                              | flex-wrap: wrap;                            |
# | font-family            | Familia tipográfica.                                                      | font-family: 'Roboto', sans-serif;          |
# | font-size              | Tamaño de la fuente.                                                      | font-size: 16px;                            |
# | font-style             | Estilo de fuente.                                                         | font-style: italic;                         |
# | font-weight            | Grosor de la fuente.                                                      | font-weight: bold;                          |
# | gap                    | Espacio entre ítems (grid/flex).                                          | gap: 1rem;                                  |
# | grid                   | Atajo para definir áreas, columnas y filas.                               | grid: auto / auto / auto;                   |
# | grid-area             | Nombre de área en el grid.                                                 | grid-area: header;                          |
# | grid-auto-columns      | Tamaño de columnas automáticas.                                           | grid-auto-columns: 200px;                   |
# | grid-auto-rows         | Tamaño de filas automáticas.                                              | grid-auto-rows: minmax(100px, auto);        |
# | grid-column            | Posición de columna.                                                      | grid-column: 1 / 3;                          |
# | grid-column-gap        | Espacio entre columnas.                                                   | grid-column-gap: 10px;                      |
# | grid-gap               | Espacio entre filas y columnas.                                           | grid-gap: 20px;                             |
# | grid-row               | Posición de fila.                                                         | grid-row: 1 / 2;                             |
# | grid-template-areas    | Define áreas con nombres.                                                 | grid-template-areas: "header header";       |
# | grid-template-columns  | Define el número y tamaño de columnas.                                   | grid-template-columns: 1fr 2fr;             |
# | grid-template-rows     | Define el número y tamaño de filas.                                      | grid-template-rows: 100px auto;             |
# | height                 | Altura del elemento.                                                      | height: 150px;                              |
# | justify-content        | Alineación en el eje principal.                                           | justify-content: space-around;              |
# | left                   | Posición izquierda (con `position`).                                     | left: 20px;                                 |
# | line-height            | Altura de línea del texto.                                                | line-height: 1.5;                           |
# | list-style             | Estilo de listas.                                                         | list-style: square inside;                  |
# | margin                 | Margen externo.                                                           | margin: 1rem;                               |
# | max-height             | Altura máxima.                                                            | max-height: 500px;                          |
# | max-width              | Ancho máximo.                                                             | max-width: 100%;                            |
# | min-height             | Altura mínima.                                                            | min-height: 200px;                          |
# | object-fit             | Ajuste de imágenes o videos.                                              | object-fit: contain;                        |
# | opacity                | Opacidad/transparencia.                                                   | opacity: 0.75;                              |
# | order                  | Orden en layout flex o grid.                                              | order: 2;                                   |
# | overflow               | Manejo de contenido que excede.                                           | overflow: scroll;                           |
# | padding                | Relleno interno.                                                          | padding: 1rem;                              |
# | place-items            | Atajo para `align-items` y `justify-items`.                              | place-items: center;                        |
# | position               | Método de posicionamiento.                                                | position: fixed;                            |
# | right                  | Posición derecha (con `position`).                                       | right: 0;                                   |
# | text-align             | Alineación del texto.                                                     | text-align: justify;                        |
# | text-decoration        | Decoración del texto (subrayado, etc.).                                  | text-decoration: none;                      |
# | text-overflow          | Cómo se corta el texto desbordado.                                        | text-overflow: ellipsis;                    |
# | text-transform         | Transformación del texto.                                                 | text-transform: capitalize;                 |
# | top                    | Posición superior (con `position`).                                      | top: 10px;                                  |
# | transform              | Aplicar transformaciones 2D/3D.                                           | transform: rotate(45deg);                   |
# | transition             | Atajo para definir transiciones suaves.                                   | transition: all 0.5s ease-in-out;           |
# | vertical-align         | Alineación vertical en línea o celdas.                                   | vertical-align: middle;                     |
# | visibility             | Control de visibilidad sin afectar el layout.                            | visibility: hidden;                         |
# | white-space            | Comportamiento del espacio en blanco.                                    | white-space: nowrap;                        |
# | width                  | Ancho del elemento.                                                       | width: 100%;                                |
# | word-break             | Comportamiento de palabras largas.                                       | word-break: break-word;                     |
# | z-index                | Profundidad en la pila de elementos.                                     | z-index: 9999;                              |
